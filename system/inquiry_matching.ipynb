# %%
import pandas as pd

path = 'C:/Users/2093/Desktop/Data Center/03. Data/05. TAITRA/FCRM/data/'
df = pd.read_csv(path + 'inquiry_utf8.csv')

def parse_date_column(s):
    """Take a Series and return a datetime-parsed Series."""
    
    dates = s.str.extract(r'(\d{2})-(\d{1,2})月 *-(\d{2})', expand=True)
    nineties = dates.iloc[:, 2].str.contains(r'8\d{1}|9\d{1}', na=False)
    millennium = dates.iloc[:, 2].str.contains(r'0\d{1}|1\d{1}', na=False)
    dates.loc[nineties, 2] = '19' + dates.loc[nineties, 2]
    dates.loc[millennium, 2] = '20' + dates.loc[millennium, 2]
    dates = pd.to_datetime(dates[0] + '-' + dates[1] + '-' + dates[2], format='%d-%m-%Y')
    return dates

for col in ['CREATION_DATE', 'LAST_UPDATE_DATE', 'PASSED_DATE']:
    df[col] = parse_date_column(df[col])
# Out:
# C:\Users\2093\AppData\Local\Continuum\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (3,10,14,15,16,17,18,25,26,28,30,34,36,37,38,39,40,41,42,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
import matplotlib.pyplot as plt

monthly_inq = df.set_index('CREATION_DATE').loc['1998':, 'OID'].resample('M').count()

plt.figure(figsize=(12, 8))
monthly_inq.plot()
monthly_inq.rolling(window=40).mean().plot()
plt.axhline(monthly_inq.mean(), color='k', linestyle='dashed')
plt.title('Total Monthly Inquiry')
plt.legend(['Monthly Inquiry', 'Rolling Mean', 'Overall Mean'])
plt.savefig('monthly_inq.jpg', dpi=300)
plt.show()

# %%
(pd.concat([df.fillna(method='bfill').iloc[1, :], df.notnull().sum() / len(df) * 100], axis=1)
 .sort_values(0, ascending=False))
# Out:
#                                                                                1  \
# OID                                                                          171
# CREATION_DATE                                                1999-08-27 00:00:00
# PRODUCT_CATEGORY_OID                                                         950
# STATUS                                                                   PUBLISH
# COMPANY_OID                                                                39475
# PRODUCT_NAME                                         Women's or girls' garments.
# CREATION_DEPT_OID                                                             NY
# LAST_UPDATE_DATE                                             2000-01-01 00:00:00
# OFFER_EXPIRATION_DATE                                                  27-11月-99
# VERIFY_YN                                                                      Y
# SOURCE_OID                                                                    60
# CREATION_USER_OID                                                             NY
# PASSED_DATE                                                  2007-04-18 00:00:00
# CONTACT_PERSON_OID                                                           108
# PRODUCT_CATEGORY_CREATION_OID                                                950
# SPECIFICATION                                                               Nuts
# PREFERRED_RESPONSE_DATE                                                10-6月 -09
# LAST_UPDATE_USER_OID                                                        G600
# PRODUCT_NAME_CREATION                                Women's or girls' garments.
# TO_ID                                                         01REP0000000060754
# TRADER_ID                                                         01REP000045411
# CONTACT_PERSON_CREATION_OID                                           2.0284e+06
# REF_NO                                                                    082722
# IMPORT_TYPE                                                                  WEB
# ESTIMATED_QUANTITY                                                             0
# SPECIFICATION_CREATION         With Brake and Chrominum Finish\rMessage:\rWe ...
# UNCLEAR_NOTE                   similar to inquiry#683489, please delete. If y...
# IS_UPDATED                                                                     Y
# AMOUNT                                                                    200000
# MUST_PROD_NAME                                                                 N
# MUST_CP_NAME                                                                   N
# MUST_CP_TEL                                                                    N
# MUST_CP_FAX                                                                    N
# MUST_SPEC                                                                      N
# MUST_PROD_CATEGORY                                                             N
# MUST_CP_EMAIL                                                                  N
# FEEDBACK                       tel and fax numbers were confirmed. Thanks!\r\...
# IS_EMAIL_ERR                                                                   Y
# PRODUCT_IMAGE_FILE                           20090606_181734_Chequered Plate.jpg
# ATTACHED_DETAIL_FILE                           20090602_092925_Specification.doc
# LAST_UPDATE_LOCAL_DATE                                                       NaN
# CREATION_LOCAL_DATE                                                          NaN
# PUBLIC_DATE                                                                  NaN
# IS_REPLY                                                                     NaN
#
#                                         0
# OID                            100.000000
# CREATION_DATE                  100.000000
# PRODUCT_CATEGORY_OID           100.000000
# STATUS                         100.000000
# COMPANY_OID                     99.985813
# PRODUCT_NAME                    99.965973
# CREATION_DEPT_OID               99.902130
# LAST_UPDATE_DATE                99.738312
# OFFER_EXPIRATION_DATE           99.690874
# VERIFY_YN                       99.556871
# SOURCE_OID                      99.077387
# CREATION_USER_OID               98.792091
# PASSED_DATE                     98.302188
# CONTACT_PERSON_OID              90.004323
# PRODUCT_CATEGORY_CREATION_OID   85.955089
# SPECIFICATION                   66.499302
# PREFERRED_RESPONSE_DATE         55.974596
# LAST_UPDATE_USER_OID            55.738179
# PRODUCT_NAME_CREATION           44.426637
# TO_ID                           44.051783
# TRADER_ID                       44.051783
# CONTACT_PERSON_CREATION_OID     41.713773
# REF_NO                          26.633637
# IMPORT_TYPE                     14.818670
# ESTIMATED_QUANTITY              12.203232
# SPECIFICATION_CREATION          11.007958
# UNCLEAR_NOTE                     8.509898
# IS_UPDATED                       6.447541
# AMOUNT                           4.977500
# MUST_PROD_NAME                   4.785418
# MUST_CP_NAME                     4.756822
# MUST_CP_TEL                      4.756822
# MUST_CP_FAX                      4.756822
# MUST_SPEC                        4.756822
# MUST_PROD_CATEGORY               4.756822
# MUST_CP_EMAIL                    4.756822
# FEEDBACK                         0.645962
# IS_EMAIL_ERR                     0.075702
# PRODUCT_IMAGE_FILE               0.042673
# ATTACHED_DETAIL_FILE             0.029705
# LAST_UPDATE_LOCAL_DATE           0.000000
# CREATION_LOCAL_DATE              0.000000
# PUBLIC_DATE                      0.000000
# IS_REPLY                         0.000000

# %%
# %%time

import string
import numpy as np
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

wnl = WordNetLemmatizer()

def process_string(s):
    processed = (s.str.strip()
                  .str.lower()
                  .str.replace(r'[\t\n\r\f\v]', r'')
                  .apply(lambda s: s.translate(str.maketrans({x: None for x in string.punctuation}))
                         if type(s) == str else np.nan)
                  .apply(lambda s: ' '.join([wnl.lemmatize(x) for x in s.split(' ') if x not in stopwords.words('english')])
                         if type(s) == str else np.nan)
                  .str.replace(r' +', r' '))
    return processed

df['PRODUCT_NAME'] = process_string(df['PRODUCT_NAME'])
df['SPECIFICATION'] = process_string(df['SPECIFICATION'])
# Out:
# Wall time: 21min 46s

# %%
pd.Series(' '.join(df['PRODUCT_NAME'].dropna()).split(' ')).value_counts().head(20)
# Out:
# product       58425
# machine       50553
# part          36557
# equipment     32033
# car           31649
# machinery     24742
# care          24291
# plastic       23619
# accessory     22391
# computer      22379
# system        19736
# tool          18110
# material      13984
# food          13459
# bicycle       12607
# steel         12254
# electronic    10920
# furniture     10280
# metal         10211
# automobile     9543
# dtype: int64
